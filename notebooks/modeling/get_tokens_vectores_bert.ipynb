# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import sys
import getpass
import numpy as np
import pandas as pd

from tqdm import tqdm

username = getpass.getuser()
sys.path.append(f'../../')

from src.data.sentence_vectorizer import SentenceVectorizer

# %%
df = pd.read_csv('../../data/interim/psytar/train.csv')
df
# Out:
#                     term  start    end  \
# 0                vertigo   63.0   70.0
# 1              dry mouth    0.0    9.0
# 2       low sexual drive   14.0   30.0
# 3     horrible migraines    0.0   18.0
# 4              no libido   11.0   20.0
# ...                  ...    ...    ...
# 3187            diarrhea  148.0  156.0
# 3188      delayed orgasm   22.0   36.0
# 3189           lose work   75.0   84.0
# 3190         feel apathy    NaN    NaN
# 3191     extreme fatigue  250.0  265.0
#
#                                                    text             norm_form  \
# 0     After the third day at that dose I found mysel...              Vertigo
# 1     Dry mouth, nausea,no sex drive, and RLS worsened.           Xerostomia
# 2                       Gain weigth & low sexual drive.     Decreased Libido
# 3     HOrrible migraines but i have had migraines si...   Migraine Disorders
# 4                      Absolutely no libido or orgasms.       Lack of libido
# ...                                                 ...                   ...
# 3187  I took it before I went to bed, Days 1 & 2 wer...             Diarrhea
# 3188  Erectile disfunction, delayed orgasm, lack of ...       Delayed orgasm
# 3189  The vertigo is rendering me unable to function...          Loss of job
# 3190  I stated I feel apathy, but I believe its beca...               Apathy
# 3191  weight gain (50+ pounds) high blood pressure s...              Fatigue
#
#             code
# 0     10047340.0
# 1     10013781.0
# 2     10024419.0
# 3     10027599.0
# 4     10024870.0
# ...          ...
# 3187  10012735.0
# 3188  10057066.0
# 3189  10024861.0
# 3190  10024642.0
# 3191  10016256.0
#
# [3192 rows x 6 columns]

# %%
sv = SentenceVectorizer()
df = sv.vectorize_span_bert(df.iloc[:100])
df
# Out:
# Some layers from the model checkpoint at bert-base-uncased were not used when initializing TFBertModel: ['nsp___cls', 'mlm___cls']
# - This IS expected if you are initializing TFBertModel from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# All the layers of TFBertModel were initialized from the model checkpoint at bert-base-uncased.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# 100%|██████████| 100/100 [00:15<00:00,  6.47it/s]
#                       term  start   end  \
# 0                  vertigo   63.0  70.0
# 1                dry mouth    0.0   9.0
# 2         low sexual drive   14.0  30.0
# 3       horrible migraines    0.0  18.0
# 4                no libido   11.0  20.0
# ..                     ...    ...   ...
# 95             mostly numb   23.0  34.0
# 96  drastic drop in libido    0.0  22.0
# 97   could not stop crying   53.0  74.0
# 98               hair loss   13.0  22.0
# 99  unable to reach orgasm   34.0  56.0
#
#                                                  text  \
# 0   After the third day at that dose I found mysel...
# 1   Dry mouth, nausea,no sex drive, and RLS worsened.
# 2                     Gain weigth & low sexual drive.
# 3   HOrrible migraines but i have had migraines si...
# 4                    Absolutely no libido or orgasms.
# ..                                                ...
# 95  Also, I also just seem mostly numb which is pr...
# 96  Drastic drop in libido, profuse sweating, decr...
# 97  Overall stoned feeling, tingly sensations, con...
# 98  Weight gain, HAIR LOSS, increased depression, ...
# 99  tired all the time, no sex drive, unable to re...
#
#                               norm_form        code  \
# 0                              Vertigo   10047340.0
# 1                           Xerostomia   10013781.0
# 2                     Decreased Libido   10024419.0
# 3                   Migraine Disorders   10027599.0
# 4                       Lack of libido   10024870.0
# ..                                  ...         ...
# 95   Loss of capacity to feel emotions   10016339.0
# 96                    Decreased Libido   10024419.0
# 97               Uncontrollable crying   10011472.0
# 98                            Alopecia   10001760.0
# 99                   Orgasm incapacity   10002652.0
#
#                                              term_vec
# 0   [-0.41556546, 0.877996, 0.36869374, -0.4746045...
# 1   [-0.026875356, 0.30081022, -0.115616515, -0.32...
# 2   [-0.062325936, -0.20301928, 0.34943816, 0.2120...
# 3   [-0.3267173, 0.93707883, 0.24313289, -0.346280...
# 4   [0.20088258, -0.600275, 0.30789685, -0.3528194...
# ..                                                ...
# 95  [-0.33629882, 0.21520269, 0.40783376, -0.17209...
# 96  [-0.26562518, -0.19444601, -0.052072108, -0.26...
# 97  [0.05883485, -0.1247714, 0.96377087, 0.4517816...
# 98  [0.6020091, 0.2893666, 0.5759104, -0.37310272,...
# 99  [-0.10766889, -0.5231218, 0.2973944, 0.0924490...
#
# [100 rows x 7 columns]
