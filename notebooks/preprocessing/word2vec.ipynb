# %%
from gensim.models import KeyedVectors

# %%
word_vectors = KeyedVectors.load_word2vec_format(
    '../../data/external/embeddings/pubmed2018_w2v_200D/pubmed2018_w2v_200D.bin', binary=True)

# %%
word_vectors.most_similar(positive=['headache'])
# Out:
# [('headaches', 0.9423099756240845),
#  ('migraines', 0.810897707939148),
#  ('dizziness', 0.7961956262588501),
#  ('tension-type', 0.7947696447372437),
#  ('migraine', 0.7862916588783264),
#  ('cephalgia', 0.7740848064422607),
#  ('side-locked', 0.7602754235267639),
#  ('headache-like', 0.7578014135360718),
#  ('migraine-type', 0.7570028901100159),
#  ('tension-type-like', 0.7546395659446716)]

# %%
word_vectors.vocab
# Out:
# {'the': <gensim.models.keyedvectors.Vocab at 0x7fe47f5eee48>,
#  'of': <gensim.models.keyedvectors.Vocab at 0x7fe47f5eeeb8>,
#  'and': <gensim.models.keyedvectors.Vocab at 0x7fe47f5eef28>,
#  'in': <gensim.models.keyedvectors.Vocab at 0x7fe47f5eef60>,
#  'to': <gensim.models.keyedvectors.Vocab at 0x7fe47f5eefd0>,
#  'a': <gensim.models.keyedvectors.Vocab at 0x7fe47f580048>,
#  'with': <gensim.models.keyedvectors.Vocab at 0x7fe47f5800b8>,
#  'for': <gensim.models.keyedvectors.Vocab at 0x7fe47f580128>,
#  'was': <gensim.models.keyedvectors.Vocab at 0x7fe47f580198>,
#  'were': <gensim.models.keyedvectors.Vocab at 0x7fe47f580208>,
#  'is': <gensim.models.keyedvectors.Vocab at 0x7fe47f580278>,
#  'by': <gensim.models.keyedvectors.Vocab at 0x7fe47f5802e8>,
#  'that': <gensim.models.keyedvectors.Vocab at 0x7fe47f580358>,
#  'on': <gensim.models.keyedvectors.Vocab at 0x7fe47f5803c8>,
#  'patients': <gensim.models.keyedvectors.Vocab at 0x7fe47f580400>,
#  'as': <gensim.models.keyedvectors.Vocab at 0x7fe47f580470>,
#  'from': <gensim.models.keyedvectors.Vocab at 0x7fe47f5804e0>,
#  'this': <gensim.models.keyedvectors.Vocab at 0x7fe47f580550>,
#  'or': <gensim.models.keyedvectors.Vocab at 0x7fe47f5805c0>,
#  'an': <gensim.models.keyedvectors.Vocab at 0x7fe47f580630>,
#  'are': <gensim.models.keyedvectors.Vocab at 0x7fe47f5806a0>,
#  'at': <gensim.models.keyedvectors.Vocab at 0x7fe47f580710>,
#  'be': <gensim.models.keyedvectors.Vocab at 0x7fe47f580780>,
#  'we': <gensim.models.keyedvectors.Vocab at 0x7fe47f5807f0>,
#  'study': <gensim.models.keyedvectors.Vocab at 0x7fe47f580860>,
#  'results': <gensim.models.keyedvectors.Vocab at 0x7fe47f5808d0>,
#  'not': <gensim.models.keyedvectors.Vocab at 0x7fe47f580940>,
#  'these': <gensim.models.keyedvectors.Vocab at 0x7fe47f5809b0>,
#  'cells': <gensim.models.keyedvectors.Vocab at 0x7fe47f580a20>,
#  'after': <gensim.models.keyedvectors.Vocab at 0x7fe47f580a90>,
#  'between': <gensim.models.keyedvectors.Vocab at 0x7fe47f580b00>,
#  'have': <gensim.models.keyedvectors.Vocab at 0x7fe47f580b70>,
#  'which': <gensim.models.keyedvectors.Vocab at 0x7fe47f580be0>,
#  'treatment': <gensim.models.keyedvectors.Vocab at 0x7fe47f580c18>,
#  'than': <gensim.models.keyedvectors.Vocab at 0x7fe47f580c88>,
#  'using': <gensim.models.keyedvectors.Vocab at 0x7fe47f580cf8>,
#  'cell': <gensim.models.keyedvectors.Vocab at 0x7fe47f580d68>,
#  'but': <gensim.models.keyedvectors.Vocab at 0x7fe47f580dd8>,
#  'been': <gensim.models.keyedvectors.Vocab at 0x7fe47f580e48>,
#  'has': <gensim.models.keyedvectors.Vocab at 0x7fe47f580eb8>,
#  'group': <gensim.models.keyedvectors.Vocab at 0x7fe47f580f28>,
#  'during': <gensim.models.keyedvectors.Vocab at 0x7fe47f580f98>,
#  'p': <gensim.models.keyedvectors.Vocab at 0x7fe47f580fd0>,
#  'both': <gensim.models.keyedvectors.Vocab at 0x7fe47f582080>,
#  'two': <gensim.models.keyedvectors.Vocab at 0x7fe47f5820f0>,
#  'may': <gensim.models.keyedvectors.Vocab at 0x7fe47f582160>,
#  'it': <gensim.models.keyedvectors.Vocab at 0x7fe47f5821d0>,
#  'their': <gensim.models.keyedvectors.Vocab at 0x7fe47f582240>,
#  'also': <gensim.models.keyedvectors.Vocab at 0x7fe47f5822b0>,
#  'had': <gensim.models.keyedvectors.Vocab at 0x7fe47f582320>,
#  'all': <gensim.models.keyedvectors.Vocab at 0x7fe47f582390>,
#  'more': <gensim.models.keyedvectors.Vocab at 0x7fe47f582400>,
#  'used': <gensim.models.keyedvectors.Vocab at 0x7fe47f582470>,
#  'no': <gensim.models.keyedvectors.Vocab at 0x7fe47f5824e0>,
#  'disease': <gensim.models.keyedvectors.Vocab at 0x7fe47f582550>,
#  'can': <gensim.models.keyedvectors.Vocab at 0x7fe47f5825c0>,
#  'clinical': <gensim.models.keyedvectors.Vocab at 0x7fe47f5825f8>,
#  'activity': <gensim.models.keyedvectors.Vocab at 0x7fe47f582630>,
#  'analysis': <gensim.models.keyedvectors.Vocab at 0x7fe47f582668>,
#  'data': <gensim.models.keyedvectors.Vocab at 0x7fe47f5826d8>,
#  '1': <gensim.models.keyedvectors.Vocab at 0x7fe47f582710>,
#  'methods': <gensim.models.keyedvectors.Vocab at 0x7fe47f582780>,
#  'expression': <gensim.models.keyedvectors.Vocab at 0x7fe47f5827b8>,
#  'protein': <gensim.models.keyedvectors.Vocab at 0x7fe47f582828>,
#  'effects': <gensim.models.keyedvectors.Vocab at 0x7fe47f582898>,
#  'effect': <gensim.models.keyedvectors.Vocab at 0x7fe47f582908>,
#  'increased': <gensim.models.keyedvectors.Vocab at 0x7fe47f582940>,
#  '2': <gensim.models.keyedvectors.Vocab at 0x7fe47f582978>,
#  'associated': <gensim.models.keyedvectors.Vocab at 0x7fe47f5829b0>,
#  'levels': <gensim.models.keyedvectors.Vocab at 0x7fe47f582a20>,
#  'compared': <gensim.models.keyedvectors.Vocab at 0x7fe47f582a58>,
#  'significantly': <gensim.models.keyedvectors.Vocab at 0x7fe47f582a90>,
#  'studies': <gensim.models.keyedvectors.Vocab at 0x7fe47f582b00>,
#  'other': <gensim.models.keyedvectors.Vocab at 0x7fe47f582b70>,
#  'human': <gensim.models.keyedvectors.Vocab at 0x7fe47f582be0>,
#  'significant': <gensim.models.keyedvectors.Vocab at 0x7fe47f582c18>,
#  'cancer': <gensim.models.keyedvectors.Vocab at 0x7fe47f582c88>,
#  'found': <gensim.models.keyedvectors.Vocab at 0x7fe47f582cf8>,
#  'one': <gensim.models.keyedvectors.Vocab at 0x7fe47f582d68>,
#  'its': <gensim.models.keyedvectors.Vocab at 0x7fe47f582dd8>,
#  'different': <gensim.models.keyedvectors.Vocab at 0x7fe47f582e10>,
#  'high': <gensim.models.keyedvectors.Vocab at 0x7fe47f582e80>,
#  'showed': <gensim.models.keyedvectors.Vocab at 0x7fe47f582ef0>,
#  'use': <gensim.models.keyedvectors.Vocab at 0x7fe47f582f60>,
#  'control': <gensim.models.keyedvectors.Vocab at 0x7fe47f582fd0>,
#  'there': <gensim.models.keyedvectors.Vocab at 0x7fe47f583080>,
#  'risk': <gensim.models.keyedvectors.Vocab at 0x7fe47f5830f0>,
#  'however': <gensim.models.keyedvectors.Vocab at 0x7fe47f583160>,
#  'years': <gensim.models.keyedvectors.Vocab at 0x7fe47f5831d0>,
#  'when': <gensim.models.keyedvectors.Vocab at 0x7fe47f583240>,
#  'into': <gensim.models.keyedvectors.Vocab at 0x7fe47f5832b0>,
#  'time': <gensim.models.keyedvectors.Vocab at 0x7fe47f583320>,
#  'our': <gensim.models.keyedvectors.Vocab at 0x7fe47f583390>,
#  'most': <gensim.models.keyedvectors.Vocab at 0x7fe47f583400>,
#  'only': <gensim.models.keyedvectors.Vocab at 0x7fe47f583470>,
#  '3': <gensim.models.keyedvectors.Vocab at 0x7fe47f5834a8>,
#  'gene': <gensim.models.keyedvectors.Vocab at 0x7fe47f583518>,
#  'cases': <gensim.models.keyedvectors.Vocab at 0x7fe47f583588>,
#  'blood': <gensim.models.keyedvectors.Vocab at 0x7fe47f5835f8>,
#  'health': <gensim.models.keyedvectors.Vocab at 0x7fe47f583668>,
#  'higher': <gensim.models.keyedvectors.Vocab at 0x7fe47f5836d8>,
#  'observed': <gensim.models.keyedvectors.Vocab at 0x7fe47f583710>,
#  'response': <gensim.models.keyedvectors.Vocab at 0x7fe47f583748>,
#  'system': <gensim.models.keyedvectors.Vocab at 0x7fe47f5837b8>,
#  'age': <gensim.models.keyedvectors.Vocab at 0x7fe47f583828>,
#  'model': <gensim.models.keyedvectors.Vocab at 0x7fe47f583898>,
#  'groups': <gensim.models.keyedvectors.Vocab at 0x7fe47f583908>,
#  'new': <gensim.models.keyedvectors.Vocab at 0x7fe47f583978>,
#  'role': <gensim.models.keyedvectors.Vocab at 0x7fe47f5839e8>,
#  '-': <gensim.models.keyedvectors.Vocab at 0x7fe47f583a20>,
#  'such': <gensim.models.keyedvectors.Vocab at 0x7fe47f583a90>,
#  'rate': <gensim.models.keyedvectors.Vocab at 0x7fe47f583b00>,
#  'three': <gensim.models.keyedvectors.Vocab at 0x7fe47f583b70>,
#  'method': <gensim.models.keyedvectors.Vocab at 0x7fe47f583be0>,
#  'present': <gensim.models.keyedvectors.Vocab at 0x7fe47f583c50>,
#  'patient': <gensim.models.keyedvectors.Vocab at 0x7fe47f583cc0>,
#  'changes': <gensim.models.keyedvectors.Vocab at 0x7fe47f583d30>,
#  'factors': <gensim.models.keyedvectors.Vocab at 0x7fe47f583da0>,
#  'who': <gensim.models.keyedvectors.Vocab at 0x7fe47f583e10>,
#  'therapy': <gensim.models.keyedvectors.Vocab at 0x7fe47f583e80>,
#  'among': <gensim.models.keyedvectors.Vocab at 0x7fe47f583ef0>,
#  'those': <gensim.models.keyedvectors.Vocab at 0x7fe47f583f60>,
#  'well': <gensim.models.keyedvectors.Vocab at 0x7fe47f583fd0>,
#  'development': <gensim.models.keyedvectors.Vocab at 0x7fe47f586048>,
#  'function': <gensim.models.keyedvectors.Vocab at 0x7fe47f5eeda0>,
#  'acid': <gensim.models.keyedvectors.Vocab at 0x7fe47f586080>,
#  'first': <gensim.models.keyedvectors.Vocab at 0x7fe47f5860f0>,
#  'respectively': <gensim.models.keyedvectors.Vocab at 0x7fe47f586128>,
#  'total': <gensim.models.keyedvectors.Vocab at 0x7fe47f586198>,
#  'increase': <gensim.models.keyedvectors.Vocab at 0x7fe47f5861d0>,
#  'children': <gensim.models.keyedvectors.Vocab at 0x7fe47f586208>,
#  'growth': <gensim.models.keyedvectors.Vocab at 0x7fe47f586278>,
#  'mean': <gensim.models.keyedvectors.Vocab at 0x7fe47f5862e8>,
#  '10': <gensim.models.keyedvectors.Vocab at 0x7fe47f586358>,
#  'care': <gensim.models.keyedvectors.Vocab at 0x7fe47f5863c8>,
#  'normal': <gensim.models.keyedvectors.Vocab at 0x7fe47f586438>,
#  'level': <gensim.models.keyedvectors.Vocab at 0x7fe47f5864a8>,
#  'type': <gensim.models.keyedvectors.Vocab at 0x7fe47f586518>,
#  'potential': <gensim.models.keyedvectors.Vocab at 0x7fe47f586550>,
#  'mice': <gensim.models.keyedvectors.Vocab at 0x7fe47f5865c0>,
#  'low': <gensim.models.keyedvectors.Vocab at 0x7fe47f586630>,
#  'case': <gensim.models.keyedvectors.Vocab at 0x7fe47f5866a0>,
#  'within': <gensim.models.keyedvectors.Vocab at 0x7fe47f586710>,
#  'performed': <gensim.models.keyedvectors.Vocab at 0x7fe47f586748>,
#  'could': <gensim.models.keyedvectors.Vocab at 0x7fe47f5867b8>,
#  'number': <gensim.models.keyedvectors.Vocab at 0x7fe47f6a9898>,
#  '5': <gensim.models.keyedvectors.Vocab at 0x7fe47f6a91d0>,
#  'important': <gensim.models.keyedvectors.Vocab at 0x7fe47f6a9978>,
#  'conclusions': <gensim.models.keyedvectors.Vocab at 0x7fe47f6a9048>,
#  'women': <gensim.models.keyedvectors.Vocab at 0x7fe47f5ee978>,
#  'rats': <gensim.models.keyedvectors.Vocab at 0x7fe47f5ee7b8>,
#  '4': <gensim.models.keyedvectors.Vocab at 0x7fe47f5eea20>,
#  'through': <gensim.models.keyedvectors.Vocab at 0x7fe47f5eea58>,
#  'each': <gensim.models.keyedvectors.Vocab at 0x7fe47f5ee908>,
#  'based': <gensim.models.keyedvectors.Vocab at 0x7fe47f5eecc0>,
#  'dna': <gensim.models.keyedvectors.Vocab at 0x7fe47f5ee710>,
#  'lower': <gensim.models.keyedvectors.Vocab at 0x7fe47f5ee518>,
#  'tumor': <gensim.models.keyedvectors.Vocab at 0x7fe47f5ee9e8>,
#  'without': <gensim.models.keyedvectors.Vocab at 0x7fe600f38748>,
#  'while': <gensim.models.keyedvectors.Vocab at 0x7fe47f6a1f28>,
#  'factor': <gensim.models.keyedvectors.Vocab at 0x7fe47f6a1c50>,
#  'findings': <gensim.models.keyedvectors.Vocab at 0x7fe47f6a1eb8>,
#  'less': <gensim.models.keyedvectors.Vocab at 0x7fe47f6a1c18>,
#  'including': <gensim.models.keyedvectors.Vocab at 0x7fe47f6a1be0>,
#  'some': <gensim.models.keyedvectors.Vocab at 0x7fe47f6a1cf8>,
#  'did': <gensim.models.keyedvectors.Vocab at 0x7fe47f586828>,
#  'tissue': <gensim.models.keyedvectors.Vocab at 0x7fe47f586898>,
#  'diagnosis': <gensim.models.keyedvectors.Vocab at 0x7fe47f5868d0>,
#  'suggest': <gensim.models.keyedvectors.Vocab at 0x7fe47f586940>,
#  'primary': <gensim.models.keyedvectors.Vocab at 0x7fe47f5869b0>,
#  'conclusion': <gensim.models.keyedvectors.Vocab at 0x7fe47f5869e8>,
#  'months': <gensim.models.keyedvectors.Vocab at 0x7fe47f586a58>,
#  'proteins': <gensim.models.keyedvectors.Vocab at 0x7fe47f586a90>,
#  'they': <gensim.models.keyedvectors.Vocab at 0x7fe47f586b00>,
#  'serum': <gensim.models.keyedvectors.Vocab at 0x7fe47f586b70>,
#  'days': <gensim.models.keyedvectors.Vocab at 0x7fe47f586be0>,
#  'over': <gensim.models.keyedvectors.Vocab at 0x7fe47f586c50>,
#  'n': <gensim.models.keyedvectors.Vocab at 0x7fe47f586c88>,
#  'receptor': <gensim.models.keyedvectors.Vocab at 0x7fe47f586cc0>,
#  'c': <gensim.models.keyedvectors.Vocab at 0x7fe47f586cf8>,
#  'identified': <gensim.models.keyedvectors.Vocab at 0x7fe47f586d30>,
#  'specific': <gensim.models.keyedvectors.Vocab at 0x7fe47f586d68>,
#  'reported': <gensim.models.keyedvectors.Vocab at 0x7fe47f586da0>,
#  'early': <gensim.models.keyedvectors.Vocab at 0x7fe47f586e10>,
#  'test': <gensim.models.keyedvectors.Vocab at 0x7fe47f586e80>,
#  'presence': <gensim.models.keyedvectors.Vocab at 0x7fe47f586eb8>,
#  'similar': <gensim.models.keyedvectors.Vocab at 0x7fe47f586f28>,
#  'differences': <gensim.models.keyedvectors.Vocab at 0x7fe47f586f60>,
#  'infection': <gensim.models.keyedvectors.Vocab at 0x7fe47f586f98>,
#  'background': <gensim.models.keyedvectors.Vocab at 0x7fe47f586fd0>,
#  'surgery': <gensim.models.keyedvectors.Vocab at 0x7fe47f588080>,
#  'reduced': <gensim.models.keyedvectors.Vocab at 0x7fe47f5880f0>,
#  'following': <gensim.models.keyedvectors.Vocab at 0x7fe47f588128>,
#  'acute': <gensim.models.keyedvectors.Vocab at 0x7fe47f588198>,
#  'treated': <gensim.models.keyedvectors.Vocab at 0x7fe47f588208>,
#  'evidence': <gensim.models.keyedvectors.Vocab at 0x7fe47f588240>,
#  'subjects': <gensim.models.keyedvectors.Vocab at 0x7fe47f588278>,
#  'under': <gensim.models.keyedvectors.Vocab at 0x7fe47f5882e8>,
#  'genes': <gensim.models.keyedvectors.Vocab at 0x7fe47f588358>,
#  'plasma': <gensim.models.keyedvectors.Vocab at 0x7fe47f5883c8>,
#  'due': <gensim.models.keyedvectors.Vocab at 0x7fe47f588438>,
#  'further': <gensim.models.keyedvectors.Vocab at 0x7fe47f5884a8>,
#  'binding': <gensim.models.keyedvectors.Vocab at 0x7fe47f588518>,
#  'obtained': <gensim.models.keyedvectors.Vocab at 0x7fe47f588550>,
#  'about': <gensim.models.keyedvectors.Vocab at 0x7fe47f5885c0>,
#  'chronic': <gensim.models.keyedvectors.Vocab at 0x7fe47f588630>,
#  '6': <gensim.models.keyedvectors.Vocab at 0x7fe47f588668>,
#  'decreased': <gensim.models.keyedvectors.Vocab at 0x7fe47f5886a0>,
#  'review': <gensim.models.keyedvectors.Vocab at 0x7fe47f588710>,
#  'conditions': <gensim.models.keyedvectors.Vocab at 0x7fe47f588748>,
#  'concentrations': <gensim.models.keyedvectors.Vocab at 0x7fe47f588780>,
#  'report': <gensim.models.keyedvectors.Vocab at 0x7fe47f5887f0>,
#  'liver': <gensim.models.keyedvectors.Vocab at 0x7fe47f588860>,
#  '95': <gensim.models.keyedvectors.Vocab at 0x7fe47f5888d0>,
#  'related': <gensim.models.keyedvectors.Vocab at 0x7fe47f588940>,
#  'measured': <gensim.models.keyedvectors.Vocab at 0x7fe47f588978>,
#  'although': <gensim.models.keyedvectors.Vocab at 0x7fe47f5889b0>,
#  'brain': <gensim.models.keyedvectors.Vocab at 0x7fe47f588a20>,
#  'studied': <gensim.models.keyedvectors.Vocab at 0x7fe47f588a90>,
#  'research': <gensim.models.keyedvectors.Vocab at 0x7fe47f588ac8>,
#  'species': <gensim.models.keyedvectors.Vocab at 0x7fe47f588b38>,
#  'induced': <gensim.models.keyedvectors.Vocab at 0x7fe47f588ba8>,
#  'addition': <gensim.models.keyedvectors.Vocab at 0x7fe47f588be0>,
#  'b': <gensim.models.keyedvectors.Vocab at 0x7fe47f588c18>,
#  'population': <gensim.models.keyedvectors.Vocab at 0x7fe47f588c50>,
#  'should': <gensim.models.keyedvectors.Vocab at 0x7fe47f588cc0>,
#  'survival': <gensim.models.keyedvectors.Vocab at 0x7fe47f588cf8>,
#  'molecular': <gensim.models.keyedvectors.Vocab at 0x7fe47f588d30>,
#  'activation': <gensim.models.keyedvectors.Vocab at 0x7fe47f588d68>,
#  'show': <gensim.models.keyedvectors.Vocab at 0x7fe47f588dd8>,
#  'drug': <gensim.models.keyedvectors.Vocab at 0x7fe47f588e48>,
#  'bone': <gensim.models.keyedvectors.Vocab at 0x7fe47f588eb8>,
#  'concentration': <gensim.models.keyedvectors.Vocab at 0x7fe47f588ef0>,
#  'positive': <gensim.models.keyedvectors.Vocab at 0x7fe47f588f28>,
#  'objective': <gensim.models.keyedvectors.Vocab at 0x7fe47f588f60>,
#  'range': <gensim.models.keyedvectors.Vocab at 0x7fe47f588fd0>,
#  'vitro': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b080>,
#  'samples': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b0f0>,
#  'revealed': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b128>,
#  'complex': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b198>,
#  'investigated': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b1d0>,
#  'developed': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b208>,
#  'period': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b278>,
#  'four': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b2e8>,
#  'major': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b358>,
#  'demonstrated': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b390>,
#  'functional': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b3c8>,
#  'several': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b438>,
#  'h': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b470>,
#  'medical': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b4e0>,
#  '12': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b550>,
#  'common': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b5c0>,
#  'against': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b630>,
#  'surface': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b6a0>,
#  '20': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b710>,
#  'i': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b748>,
#  'examined': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b780>,
#  'approach': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b7b8>,
#  'pressure': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b7f0>,
#  'syndrome': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b828>,
#  't': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b860>,
#  'determined': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b898>,
#  'rates': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b908>,
#  'small': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b978>,
#  'information': <gensim.models.keyedvectors.Vocab at 0x7fe47f58b9b0>,
#  'before': <gensim.models.keyedvectors.Vocab at 0x7fe47f58ba20>,
#  'either': <gensim.models.keyedvectors.Vocab at 0x7fe47f58ba90>,
#  'values': <gensim.models.keyedvectors.Vocab at 0x7fe47f58bb00>,
#  'structure': <gensim.models.keyedvectors.Vocab at 0x7fe47f58bb38>,
#  'determine': <gensim.models.keyedvectors.Vocab at 0x7fe47f58bb70>,
#  'formation': <gensim.models.keyedvectors.Vocab at 0x7fe47f58bba8>,
#  'rat': <gensim.models.keyedvectors.Vocab at 0x7fe47f58bc18>,
#  'single': <gensim.models.keyedvectors.Vocab at 0x7fe47f58bc88>,
#  'large': <gensim.models.keyedvectors.Vocab at 0x7fe47f58bcf8>,
#  'production': <gensim.models.keyedvectors.Vocab at 0x7fe47f58bd30>,
#  'pain': <gensim.models.keyedvectors.Vocab at 0x7fe47f58bda0>,
#  'evaluated': <gensim.models.keyedvectors.Vocab at 0x7fe47f58bdd8>,
#  'vs': <gensim.models.keyedvectors.Vocab at 0x7fe47f58be48>,
#  'various': <gensim.models.keyedvectors.Vocab at 0x7fe47f58beb8>,
#  'effective': <gensim.models.keyedvectors.Vocab at 0x7fe47f58bef0>,
#  'whether': <gensim.models.keyedvectors.Vocab at 0x7fe47f58bf60>,
#  'body': <gensim.models.keyedvectors.Vocab at 0x7fe47f58bfd0>,
#  'association': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e048>,
#  'greater': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e0b8>,
#  'management': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e0f0>,
#  'muscle': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e160>,
#  'multiple': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e198>,
#  'same': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e208>,
#  'quality': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e278>,
#  'responses': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e2b0>,
#  'heart': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e320>,
#  'ii': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e390>,
#  'novel': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e400>,
#  'process': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e470>,
#  'exposure': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e4a8>,
#  'symptoms': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e4e0>,
#  'current': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e550>,
#  'included': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e588>,
#  'thus': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e5f8>,
#  'ci': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e668>,
#  'shown': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e6d8>,
#  'per': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e748>,
#  '30': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e7b8>,
#  'mechanisms': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e7f0>,
#  'surgical': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e828>,
#  'many': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e898>,
#  'dose': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e908>,
#  'possible': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e940>,
#  'renal': <gensim.models.keyedvectors.Vocab at 0x7fe47f58e9b0>,
#  'whereas': <gensim.models.keyedvectors.Vocab at 0x7fe47f58ea20>,
#  'membrane': <gensim.models.keyedvectors.Vocab at 0x7fe47f58ea58>,
#  'properties': <gensim.models.keyedvectors.Vocab at 0x7fe47f58ea90>,
#  '15': <gensim.models.keyedvectors.Vocab at 0x7fe47f58eb00>,
#  'provide': <gensim.models.keyedvectors.Vocab at 0x7fe47f58eb70>,
#  'because': <gensim.models.keyedvectors.Vocab at 0x7fe47f58ebe0>,
#  'detected': <gensim.models.keyedvectors.Vocab at 0x7fe47f58ec18>,
#  'involved': <gensim.models.keyedvectors.Vocab at 0x7fe47f58ec50>,
#  'phase': <gensim.models.keyedvectors.Vocab at 0x7fe47f58ecc0>,
#  'ratio': <gensim.models.keyedvectors.Vocab at 0x7fe47f58ed30>,
#  'virus': <gensim.models.keyedvectors.Vocab at 0x7fe47f58eda0>,
#  'here': <gensim.models.keyedvectors.Vocab at 0x7fe47f58ee10>,
#  'evaluation': <gensim.models.keyedvectors.Vocab at 0x7fe47f58ee48>,
#  'mortality': <gensim.models.keyedvectors.Vocab at 0x7fe47f58ee80>,
#  'lung': <gensim.models.keyedvectors.Vocab at 0x7fe47f58eef0>,
#  'stress': <gensim.models.keyedvectors.Vocab at 0x7fe47f58ef60>,
#  'will': <gensim.models.keyedvectors.Vocab at 0x7fe47f58efd0>,
#  'change': <gensim.models.keyedvectors.Vocab at 0x7fe47f592080>,
#  'genetic': <gensim.models.keyedvectors.Vocab at 0x7fe47f5920f0>,
#  'vivo': <gensim.models.keyedvectors.Vocab at 0x7fe47f592160>,
#  'reduction': <gensim.models.keyedvectors.Vocab at 0x7fe47f592198>,
#  'inhibition': <gensim.models.keyedvectors.Vocab at 0x7fe47f5921d0>,
#  'weight': <gensim.models.keyedvectors.Vocab at 0x7fe47f592240>,
#  'known': <gensim.models.keyedvectors.Vocab at 0x7fe47f5922b0>,
#  'controls': <gensim.models.keyedvectors.Vocab at 0x7fe47f5922e8>,
#  'weeks': <gensim.models.keyedvectors.Vocab at 0x7fe47f592358>,
#  'mechanism': <gensim.models.keyedvectors.Vocab at 0x7fe47f592390>,
#  'imaging': <gensim.models.keyedvectors.Vocab at 0x7fe47f592400>,
#  'isolated': <gensim.models.keyedvectors.Vocab at 0x7fe47f592438>,
#  'outcome': <gensim.models.keyedvectors.Vocab at 0x7fe47f5924a8>,
#  'any': <gensim.models.keyedvectors.Vocab at 0x7fe47f592518>,
#  'loss': <gensim.models.keyedvectors.Vocab at 0x7fe47f592588>,
#  'region': <gensim.models.keyedvectors.Vocab at 0x7fe47f5925f8>,
#  'hospital': <gensim.models.keyedvectors.Vocab at 0x7fe47f592630>,
#  'experimental': <gensim.models.keyedvectors.Vocab at 0x7fe47f592668>,
#  'difference': <gensim.models.keyedvectors.Vocab at 0x7fe47f5926a0>,
#  'resistance': <gensim.models.keyedvectors.Vocab at 0x7fe47f5926d8>,
#  'detection': <gensim.models.keyedvectors.Vocab at 0x7fe47f592710>,
#  'water': <gensim.models.keyedvectors.Vocab at 0x7fe47f592780>,
#  'models': <gensim.models.keyedvectors.Vocab at 0x7fe47f5927f0>,
#  '50': <gensim.models.keyedvectors.Vocab at 0x7fe47f592860>,
#  'diseases': <gensim.models.keyedvectors.Vocab at 0x7fe47f592898>,
#  'injury': <gensim.models.keyedvectors.Vocab at 0x7fe47f592908>,
#  'severe': <gensim.models.keyedvectors.Vocab at 0x7fe47f592978>,
#  'size': <gensim.models.keyedvectors.Vocab at 0x7fe47f5929e8>,
#  'assessed': <gensim.models.keyedvectors.Vocab at 0x7fe47f592a20>,
#  'follow-up': <gensim.models.keyedvectors.Vocab at 0x7fe47f592a58>,
#  'out': <gensim.models.keyedvectors.Vocab at 0x7fe47f592ac8>,
#  'mass': <gensim.models.keyedvectors.Vocab at 0x7fe47f592b38>,
#  'active': <gensim.models.keyedvectors.Vocab at 0x7fe47f592ba8>,
#  'technique': <gensim.models.keyedvectors.Vocab at 0x7fe47f592be0>,
#  'relationship': <gensim.models.keyedvectors.Vocab at 0x7fe47f592c18>,
#  'reaction': <gensim.models.keyedvectors.Vocab at 0x7fe47f592c50>,
#  'mm': <gensim.models.keyedvectors.Vocab at 0x7fe47f592cc0>,
#  'design': <gensim.models.keyedvectors.Vocab at 0x7fe47f592d30>,
#  'overall': <gensim.models.keyedvectors.Vocab at 0x7fe47f592da0>,
#  'outcomes': <gensim.models.keyedvectors.Vocab at 0x7fe47f592dd8>,
#  'performance': <gensim.models.keyedvectors.Vocab at 0x7fe47f592e10>,
#  'characteristics': <gensim.models.keyedvectors.Vocab at 0x7fe47f592e48>,
#  'flow': <gensim.models.keyedvectors.Vocab at 0x7fe47f592eb8>,
#  'if': <gensim.models.keyedvectors.Vocab at 0x7fe47f592f28>,
#  'administration': <gensim.models.keyedvectors.Vocab at 0x7fe47f592f60>,
#  'synthesis': <gensim.models.keyedvectors.Vocab at 0x7fe47f592f98>,
#  'breast': <gensim.models.keyedvectors.Vocab at 0x7fe47f594048>,
#  'cardiac': <gensim.models.keyedvectors.Vocab at 0x7fe47f5940b8>,
#  'support': <gensim.models.keyedvectors.Vocab at 0x7fe47f594128>,
#  'influence': <gensim.models.keyedvectors.Vocab at 0x7fe47f594160>,
#  'lesions': <gensim.models.keyedvectors.Vocab at 0x7fe47f5941d0>,
#  'aim': <gensim.models.keyedvectors.Vocab at 0x7fe47f594240>,
#  'area': <gensim.models.keyedvectors.Vocab at 0x7fe47f5942b0>,
#  'up': <gensim.models.keyedvectors.Vocab at 0x7fe47f594320>,
#  'purpose': <gensim.models.keyedvectors.Vocab at 0x7fe47f594390>,
#  'recent': <gensim.models.keyedvectors.Vocab at 0x7fe47f594400>,
#  'analyzed': <gensim.models.keyedvectors.Vocab at 0x7fe47f594438>,
#  '7': <gensim.models.keyedvectors.Vocab at 0x7fe47f594470>,
#  'systems': <gensim.models.keyedvectors.Vocab at 0x7fe47f5944e0>,
#  'day': <gensim.models.keyedvectors.Vocab at 0x7fe47f594550>,
#  'parameters': <gensim.models.keyedvectors.Vocab at 0x7fe47f594588>,
#  'family': <gensim.models.keyedvectors.Vocab at 0x7fe47f5945f8>,
#  'value': <gensim.models.keyedvectors.Vocab at 0x7fe47f594668>,
#  '8': <gensim.models.keyedvectors.Vocab at 0x7fe47f5946a0>,
#  'assessment': <gensim.models.keyedvectors.Vocab at 0x7fe47f5946d8>,
#  'decrease': <gensim.models.keyedvectors.Vocab at 0x7fe47f594710>,
#  'presented': <gensim.models.keyedvectors.Vocab at 0x7fe47f594748>,
#  'status': <gensim.models.keyedvectors.Vocab at 0x7fe47f5947b8>,
#  'contrast': <gensim.models.keyedvectors.Vocab at 0x7fe47f5947f0>,
#  'available': <gensim.models.keyedvectors.Vocab at 0x7fe47f594828>,
#  'life': <gensim.models.keyedvectors.Vocab at 0x7fe47f594898>,
#  'animals': <gensim.models.keyedvectors.Vocab at 0x7fe47f594908>,
#  'very': <gensim.models.keyedvectors.Vocab at 0x7fe47f594978>,
#  'general': <gensim.models.keyedvectors.Vocab at 0x7fe47f5949e8>,
#  'incidence': <gensim.models.keyedvectors.Vocab at 0x7fe47f594a20>,
#  'indicate': <gensim.models.keyedvectors.Vocab at 0x7fe47f594a58>,
#  'tumors': <gensim.models.keyedvectors.Vocab at 0x7fe47f594ac8>,
#  'sensitivity': <gensim.models.keyedvectors.Vocab at 0x7fe47f594b00>,
#  '±': <gensim.models.keyedvectors.Vocab at 0x7fe47f594b38>,
#  'therapeutic': <gensim.models.keyedvectors.Vocab at 0x7fe47f594b70>,
#  'evaluate': <gensim.models.keyedvectors.Vocab at 0x7fe47f594ba8>,
#  'previously': <gensim.models.keyedvectors.Vocab at 0x7fe47f594be0>,
#  '100': <gensim.models.keyedvectors.Vocab at 0x7fe47f594c50>,
#  'enzyme': <gensim.models.keyedvectors.Vocab at 0x7fe47f594cc0>,
#  'healthy': <gensim.models.keyedvectors.Vocab at 0x7fe47f594d30>,
#  'therefore': <gensim.models.keyedvectors.Vocab at 0x7fe47f594d68>,
#  'caused': <gensim.models.keyedvectors.Vocab at 0x7fe47f594dd8>,
#  '24': <gensim.models.keyedvectors.Vocab at 0x7fe47f594e48>,
#  'sequence': <gensim.models.keyedvectors.Vocab at 0x7fe47f594e80>,
#  'required': <gensim.models.keyedvectors.Vocab at 0x7fe47f594eb8>,
#  'form': <gensim.models.keyedvectors.Vocab at 0x7fe47f594f28>,
#  'comparison': <gensim.models.keyedvectors.Vocab at 0x7fe47f594f60>,
#  'male': <gensim.models.keyedvectors.Vocab at 0x7fe47f594fd0>,
#  'left': <gensim.models.keyedvectors.Vocab at 0x7fe47f598080>,
#  'carcinoma': <gensim.models.keyedvectors.Vocab at 0x7fe47f5980b8>,
#  'highly': <gensim.models.keyedvectors.Vocab at 0x7fe47f598128>,
#  'correlation': <gensim.models.keyedvectors.Vocab at 0x7fe47f598160>,
#  'negative': <gensim.models.keyedvectors.Vocab at 0x7fe47f598198>,
#  'frequency': <gensim.models.keyedvectors.Vocab at 0x7fe47f5981d0>,
#  'diabetes': <gensim.models.keyedvectors.Vocab at 0x7fe47f598208>,
#  'result': <gensim.models.keyedvectors.Vocab at 0x7fe47f598278>,
#  'distribution': <gensim.models.keyedvectors.Vocab at 0x7fe47f5982b0>,
#  'via': <gensim.models.keyedvectors.Vocab at 0x7fe47f598320>,
#  'five': <gensim.models.keyedvectors.Vocab at 0x7fe47f598390>,
#  'work': <gensim.models.keyedvectors.Vocab at 0x7fe47f598400>,
#  'site': <gensim.models.keyedvectors.Vocab at 0x7fe47f598470>,
#  'drugs': <gensim.models.keyedvectors.Vocab at 0x7fe47f5984e0>,
#  'sites': <gensim.models.keyedvectors.Vocab at 0x7fe47f598550>,
#  'tested': <gensim.models.keyedvectors.Vocab at 0x7fe47f5985c0>,
#  'release': <gensim.models.keyedvectors.Vocab at 0x7fe47f598630>,
#  'pulmonary': <gensim.models.keyedvectors.Vocab at 0x7fe47f598668>,
#  '005': <gensim.models.keyedvectors.Vocab at 0x7fe47f5986d8>,
#  'being': <gensim.models.keyedvectors.Vocab at 0x7fe47f598748>,
#  'complications': <gensim.models.keyedvectors.Vocab at 0x7fe47f598780>,
#  'prevalence': <gensim.models.keyedvectors.Vocab at 0x7fe47f5987b8>,
#  'impact': <gensim.models.keyedvectors.Vocab at 0x7fe47f598828>,
#  'how': <gensim.models.keyedvectors.Vocab at 0x7fe47f598898>,
#  'death': <gensim.models.keyedvectors.Vocab at 0x7fe47f598908>,
#  'described': <gensim.models.keyedvectors.Vocab at 0x7fe47f598940>,
#  'receptors': <gensim.models.keyedvectors.Vocab at 0x7fe47f598978>,
#  'failure': <gensim.models.keyedvectors.Vocab at 0x7fe47f5989e8>,
#  'adult': <gensim.models.keyedvectors.Vocab at 0x7fe47f598a58>,
#  'oral': <gensim.models.keyedvectors.Vocab at 0x7fe47f598ac8>,
#  'combination': <gensim.models.keyedvectors.Vocab at 0x7fe47f598b00>,
#  'followed': <gensim.models.keyedvectors.Vocab at 0x7fe47f598b38>,
#  'state': <gensim.models.keyedvectors.Vocab at 0x7fe47f598ba8>,
#  'mrna': <gensim.models.keyedvectors.Vocab at 0x7fe47f598c18>,
#  'types': <gensim.models.keyedvectors.Vocab at 0x7fe47f598c88>,
#  'order': <gensim.models.keyedvectors.Vocab at 0x7fe47f598cf8>,
#  'considered': <gensim.models.keyedvectors.Vocab at 0x7fe47f598d30>,
#  'interaction': <gensim.models.keyedvectors.Vocab at 0x7fe47f598d68>,
#  'standard': <gensim.models.keyedvectors.Vocab at 0x7fe47f598da0>,
#  'skin': <gensim.models.keyedvectors.Vocab at 0x7fe47f598e10>,
#  'improved': <gensim.models.keyedvectors.Vocab at 0x7fe47f598e48>,
#  '25': <gensim.models.keyedvectors.Vocab at 0x7fe47f598eb8>,
#  'participants': <gensim.models.keyedvectors.Vocab at 0x7fe47f598ef0>,
#  'assay': <gensim.models.keyedvectors.Vocab at 0x7fe47f598f60>,
#  'index': <gensim.models.keyedvectors.Vocab at 0x7fe47f598fd0>,
#  'disorders': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b048>,
#  'expressed': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b080>,
#  'physical': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b0b8>,
#  'relative': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b0f0>,
#  'second': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b160>,
#  'individuals': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b198>,
#  'artery': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b208>,
#  'produced': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b240>,
#  'glucose': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b2b0>,
#  'then': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b320>,
#  'increasing': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b358>,
#  'target': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b3c8>,
#  'better': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b438>,
#  'investigate': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b470>,
#  'efficacy': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b4a8>,
#  'central': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b518>,
#  'ability': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b588>,
#  'stimulation': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b5c0>,
#  'received': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b5f8>,
#  'cellular': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b630>,
#  'cause': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b6a0>,
#  'stage': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b710>,
#  'men': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b780>,
#  'long-term': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b7b8>,
#  'mouse': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b828>,
#  'features': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b860>,
#  'identify': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b898>,
#  'coronary': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b8d0>,
#  'pathway': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b940>,
#  'sample': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b9b0>,
#  'vascular': <gensim.models.keyedvectors.Vocab at 0x7fe47f59b9e8>,
#  'activities': <gensim.models.keyedvectors.Vocab at 0x7fe47f59ba20>,
#  'content': <gensim.models.keyedvectors.Vocab at 0x7fe47f59ba90>,
#  'given': <gensim.models.keyedvectors.Vocab at 0x7fe47f59bb00>,
#  'assess': <gensim.models.keyedvectors.Vocab at 0x7fe47f59bb70>,
#  '14': <gensim.models.keyedvectors.Vocab at 0x7fe47f59bbe0>,
#  'antibodies': <gensim.models.keyedvectors.Vocab at 0x7fe47f59bc18>,
#  'initial': <gensim.models.keyedvectors.Vocab at 0x7fe47f59bc88>,
#  'part': <gensim.models.keyedvectors.Vocab at 0x7fe47f59bcf8>,
#  'previous': <gensim.models.keyedvectors.Vocab at 0x7fe47f59bd30>,
#  'immune': <gensim.models.keyedvectors.Vocab at 0x7fe47f59bda0>,
#  'regulation': <gensim.models.keyedvectors.Vocab at 0x7fe47f59bdd8>,
#  'volume': <gensim.models.keyedvectors.Vocab at 0x7fe47f59be48>,
#  'combined': <gensim.models.keyedvectors.Vocab at 0x7fe47f59be80>,
#  'diagnostic': <gensim.models.keyedvectors.Vocab at 0x7fe47f59beb8>,
#  'neurons': <gensim.models.keyedvectors.Vocab at 0x7fe47f59bf28>,
#  '11': <gensim.models.keyedvectors.Vocab at 0x7fe47f59bf98>,
#  'literature': <gensim.models.keyedvectors.Vocab at 0x7fe47f59bfd0>,
#  'compounds': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f048>,
#  'insulin': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f0b8>,
#  'average': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f128>,
#  'tissues': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f198>,
#  'strains': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f208>,
#  'measurements': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f240>,
#  'correlated': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f278>,
#  'analyses': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f2b0>,
#  'indicated': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f2e8>,
#  'likely': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f358>,
#  'where': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f3c8>,
#  'main': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f438>,
#  'six': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f4a8>,
#  'versus': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f518>,
#  'patterns': <gensim.models.keyedvectors.Vocab at 0x7fe47fdc45c0>,
#  'practice': <gensim.models.keyedvectors.Vocab at 0x7fe6017b2a58>,
#  'demonstrate': <gensim.models.keyedvectors.Vocab at 0x7fe47f6a1cc0>,
#  'female': <gensim.models.keyedvectors.Vocab at 0x7fe47f6a1ef0>,
#  'measures': <gensim.models.keyedvectors.Vocab at 0x7fe47f6a1fd0>,
#  'local': <gensim.models.keyedvectors.Vocab at 0x7fe47f6a1e80>,
#  'conducted': <gensim.models.keyedvectors.Vocab at 0x7fe47f6a1e48>,
#  'procedure': <gensim.models.keyedvectors.Vocab at 0x7fe47f6a1f60>,
#  'pattern': <gensim.models.keyedvectors.Vocab at 0x7fe600f38240>,
#  'behavior': <gensim.models.keyedvectors.Vocab at 0x7fe600f38320>,
#  'action': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f588>,
#  'interactions': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f5c0>,
#  'temperature': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f5f8>,
#  'direct': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f668>,
#  'energy': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f6d8>,
#  'need': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f748>,
#  'least': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f7b8>,
#  'individual': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f7f0>,
#  'techniques': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f828>,
#  'degrees': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f898>,
#  'x': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f8d0>,
#  'application': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f908>,
#  'signaling': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f940>,
#  'even': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f9b0>,
#  'experiments': <gensim.models.keyedvectors.Vocab at 0x7fe47f59f9e8>,
#  'mg': <gensim.models.keyedvectors.Vocab at 0x7fe47f59fa58>,
#  'often': <gensim.models.keyedvectors.Vocab at 0x7fe47f59fac8>,
#  'characterized': <gensim.models.keyedvectors.Vocab at 0x7fe47f59fb00>,
#  'might': <gensim.models.keyedvectors.Vocab at 0x7fe47f59fb70>,
#  's': <gensim.models.keyedvectors.Vocab at 0x7fe47f59fba8>,
#  'applied': <gensim.models.keyedvectors.Vocab at 0x7fe47f59fc18>,
#  'screening': <gensim.models.keyedvectors.Vocab at 0x7fe47f59fc50>,
#  'median': <gensim.models.keyedvectors.Vocab at 0x7fe47f59fcc0>,
#  'ph': <gensim.models.keyedvectors.Vocab at 0x7fe47f59fd30>,
#  'made': <gensim.models.keyedvectors.Vocab at 0x7fe47f59fda0>,
#  'tests': <gensim.models.keyedvectors.Vocab at 0x7fe47f59fe10>,
#  'd': <gensim.models.keyedvectors.Vocab at 0x7fe47f59fe48>,
#  'intervention': <gensim.models.keyedvectors.Vocab at 0x7fe47f59fe80>,
#  'good': <gensim.models.keyedvectors.Vocab at 0x7fe47f59fef0>,
#  '0001': <gensim.models.keyedvectors.Vocab at 0x7fe47f59ff60>,
#  'approximately': <gensim.models.keyedvectors.Vocab at 0x7fe47f59ff98>,
#  'field': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2048>,
#  'areas': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a20b8>,
#  '18': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2128>,
#  'regions': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2198>,
#  'events': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2208>,
#  'kinase': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2278>,
#  'year': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a22e8>,
#  'containing': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2320>,
#  'biological': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2358>,
#  'trials': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a23c8>,
#  '40': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2438>,
#  'social': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a24a8>,
#  'culture': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2518>,
#  'occurred': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2550>,
#  'mutations': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2588>,
#  'antibody': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a25c0>,
#  'min': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2630>,
#  'trial': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a26a0>,
#  'complete': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a26d8>,
#  'underwent': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2710>,
#  'adults': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2780>,
#  'processes': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a27b8>,
#  'light': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2828>,
#  'm': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2860>,
#  'agents': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a28d0>,
#  'according': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2908>,
#  'inhibitor': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2940>,
#  'furthermore': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2978>,
#  'understanding': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a29b0>,
#  'useful': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2a20>,
#  'enhanced': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2a58>,
#  'since': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2ac8>,
#  '16': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2b38>,
#  'increases': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2b70>,
#  'rna': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2be0>,
#  'knowledge': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2c18>,
#  'resulted': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2c50>,
#  'improve': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2cc0>,
#  'score': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2d30>,
#  'times': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2da0>,
#  'examination': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2dd8>,
#  'metabolism': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2e10>,
#  'secondary': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2e48>,
#  'discussed': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2e80>,
#  'affected': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2eb8>,
#  'does': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2f28>,
#  'baseline': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2f60>,
#  '001': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a2fd0>,
#  'would': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5080>,
#  'paper': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a50f0>,
#  'history': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5160>,
#  'peripheral': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5198>,
#  'seen': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5208>,
#  'independent': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5240>,
#  'proliferation': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5278>,
#  'amino': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a52e8>,
#  'free': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5358>,
#  'inhibited': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5390>,
#  'density': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5400>,
#  'structures': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5438>,
#  'them': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a54a8>,
#  'nerve': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5518>,
#  'suggesting': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5550>,
#  'additional': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5588>,
#  'suggests': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a55c0>,
#  'suggested': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a55f8>,
#  '13': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5668>,
#  'structural': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a56a0>,
#  '60': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5710>,
#  'apoptosis': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5748>,
#  'postoperative': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5780>,
#  'inflammatory': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a57b8>,
#  'confirmed': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a57f0>,
#  'damage': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5860>,
#  'duration': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5898>,
#  'differentiation': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a58d0>,
#  'right': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5940>,
#  'regression': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5978>,
#  'strain': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a59e8>,
#  'pregnancy': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5a20>,
#  'collected': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5a58>,
#  'visual': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5ac8>,
#  'metabolic': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5b00>,
#  'injection': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5b38>,
#  'do': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5ba8>,
#  'training': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5be0>,
#  'future': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5c50>,
#  'acids': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5cc0>,
#  'critical': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5cf8>,
#  'rapid': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5d68>,
#  'disorder': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5da0>,
#  'basis': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5e10>,
#  'experience': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5e48>,
#  'infections': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5e80>,
#  'length': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5ef0>,
#  'proposed': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5f28>,
#  'functions': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5f60>,
#  'induction': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a5f98>,
#  'key': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9048>,
#  'limited': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a90b8>,
#  'identification': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a90f0>,
#  'essential': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9128>,
#  'calcium': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9198>,
#  'components': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a91d0>,
#  'selected': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9208>,
#  '9': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9240>,
#  'e': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9278>,
#  'andor': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a92e8>,
#  'materials': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9320>,
#  'authors': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9390>,
#  'controlled': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a93c8>,
#  'testing': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9438>,
#  'problems': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9470>,
#  'oxygen': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a94e0>,
#  'inhibitors': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9518>,
#  'criteria': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9550>,
#  'lines': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a95c0>,
#  'scores': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9630>,
#  'nuclear': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a96a0>,
#  'improvement': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a96d8>,
#  'provides': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9710>,
#  'molecules': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9748>,
#  'established': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9780>,
#  'across': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a97f0>,
#  'kidney': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9860>,
#  'respiratory': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9898>,
#  'depression': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a98d0>,
#  'hypertension': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9908>,
#  'recently': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9940>,
#  'transcription': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9978>,
#  'exercise': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a99b0>,
#  'ventricular': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a99e8>,
#  'especially': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9a20>,
#  'solution': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9a58>,
#  'alone': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9ac8>,
#  'series': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9b38>,
#  'populations': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9b70>,
#  'absence': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9be0>,
#  'pathways': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9c18>,
#  'importance': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9c50>,
#  'scale': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9cc0>,
#  'cardiovascular': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9cf8>,
#  'lead': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9d68>,
#  'young': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9dd8>,
#  'affect': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9e48>,
#  'strategies': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9e80>,
#  'despite': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9ef0>,
#  'lipid': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9f60>,
#  'elevated': <gensim.models.keyedvectors.Vocab at 0x7fe47f5a9f98>,
#  'food': <gensim.models.keyedvectors.Vocab at 0x7fe47f5ad048>,
#  'bacterial': <gensim.models.keyedvectors.Vocab at 0x7fe47f5ad080>,
#  'domain': <gensim.models.keyedvectors.Vocab at 0x7fe47f5ad0f0>,
#  'quantitative': <gensim.models.keyedvectors.Vocab at 0x7fe47f5ad128>,
#  'myocardial': <gensim.models.keyedvectors.Vocab at 0x7fe47f5ad160>,
#  'states': <gensim.models.keyedvectors.Vocab at 0x7fe47f5ad1d0>,
#  'hours': <gensim.models.keyedvectors.Vocab at 0x7fe47f5ad240>,
#  'peptide': <gensim.models.keyedvectors.Vocab at 0x7fe47f5ad2b0>,
#  'daily': <gensim.models.keyedvectors.Vocab at 0x7fe47f5ad320>,
#  'play': <gensim.models.keyedvectors.Vocab at 0x7fe47f5ad390>,
#  'alpha': <gensim.models.keyedvectors.Vocab at 0x7fe47f5ad400>,
#  'electron': <gensim.models.keyedvectors.Vocab at 0x7fe47f5ad438>,
#  'program': <gensim.models.keyedvectors.Vocab at 0x7fe47f5ad4a8>,
#  'still': <gensim.models.keyedvectors.Vocab at 0x7fe47f5ad518>,
#  'uptake': <gensim.models.keyedvectors.Vocab at 0x7fe47f5ad588>,
#  'cerebral': <gensim.models.keyedvectors.Vocab at 0x7fe47f5ad5c0>,
# ...
#  'products': <gensim.models.keyedvectors.Vocab at 0x7fe47f5adf60>,
#  'signal': <gensim.models.keyedvectors.Vocab at 0x7fe47f5adfd0>,
#  'mutation': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af048>,
#  'sequences': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af080>,
#  'long': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af0f0>,
#  'ct': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af160>,
#  'antigen': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af1d0>,
#  'provided': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af208>,
#  'reduce': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af278>,
#  'transport': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af2b0>,
#  'safety': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af320>,
#  'interval': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af358>,
#  'line': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af3c8>,
#  'transplantation': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af400>,
#  'chemotherapy': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af438>,
#  'endothelial': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af470>,
#  'capacity': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af4a8>,
#  'article': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af518>,
#  'cycle': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af588>,
#  'derived': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af5f8>,
#  'cognitive': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af630>,
#  'aged': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af6a0>,
#  'simple': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af710>,
#  'stem': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af780>,
#  'measurement': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af7b8>,
#  'end': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af828>,
#  'diagnosed': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af860>,
#  'transfer': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af898>,
#  'secretion': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af8d0>,
#  'sex': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af940>,
#  'infants': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af9b0>,
#  'progression': <gensim.models.keyedvectors.Vocab at 0x7fe47f5af9e8>,
#  'iii': <gensim.models.keyedvectors.Vocab at 0x7fe47f5afa58>,
#  'diet': <gensim.models.keyedvectors.Vocab at 0x7fe47f5afac8>,
#  'variation': <gensim.models.keyedvectors.Vocab at 0x7fe47f5afb00>,
#  'achieved': <gensim.models.keyedvectors.Vocab at 0x7fe47f5afb38>,
#  'adverse': <gensim.models.keyedvectors.Vocab at 0x7fe47f5afba8>,
#  'cohort': <gensim.models.keyedvectors.Vocab at 0x7fe47f5afc18>,
#  'us': <gensim.models.keyedvectors.Vocab at 0x7fe47f5afc88>,
#  'remains': <gensim.models.keyedvectors.Vocab at 0x7fe47f5afcf8>,
#  'together': <gensim.models.keyedvectors.Vocab at 0x7fe47f5afd30>,
#  'conventional': <gensim.models.keyedvectors.Vocab at 0x7fe47f5afd68>,
#  'medium': <gensim.models.keyedvectors.Vocab at 0x7fe47f5afdd8>,
#  'material': <gensim.models.keyedvectors.Vocab at 0x7fe47f5afe10>,
#  'degree': <gensim.models.keyedvectors.Vocab at 0x7fe47f5afe80>,
#  'coli': <gensim.models.keyedvectors.Vocab at 0x7fe47f5afef0>,
#  'moreover': <gensim.models.keyedvectors.Vocab at 0x7fe47f5aff28>,
#  'arterial': <gensim.models.keyedvectors.Vocab at 0x7fe47f5aff60>,
#  'stable': <gensim.models.keyedvectors.Vocab at 0x7fe47f5affd0>,
#  'prospective': <gensim.models.keyedvectors.Vocab at 0x7fe40038d048>,
#  'particularly': <gensim.models.keyedvectors.Vocab at 0x7fe40038d080>,
#  'monitoring': <gensim.models.keyedvectors.Vocab at 0x7fe40038d0b8>,
#  'few': <gensim.models.keyedvectors.Vocab at 0x7fe40038d128>,
#  'poor': <gensim.models.keyedvectors.Vocab at 0x7fe40038d198>,
#  'sensitive': <gensim.models.keyedvectors.Vocab at 0x7fe40038d1d0>,
#  'radiation': <gensim.models.keyedvectors.Vocab at 0x7fe40038d208>,
#  'mgkg': <gensim.models.keyedvectors.Vocab at 0x7fe40038d278>,
#  'class': <gensim.models.keyedvectors.Vocab at 0x7fe40038d2e8>,
#  'variables': <gensim.models.keyedvectors.Vocab at 0x7fe40038d320>,
#  'condition': <gensim.models.keyedvectors.Vocab at 0x7fe40038d358>,
#  'hiv': <gensim.models.keyedvectors.Vocab at 0x7fe40038d3c8>,
#  'specificity': <gensim.models.keyedvectors.Vocab at 0x7fe40038d400>,
#  'statistically': <gensim.models.keyedvectors.Vocab at 0x7fe40038d438>,
#  'particular': <gensim.models.keyedvectors.Vocab at 0x7fe40038d470>,
#  'side': <gensim.models.keyedvectors.Vocab at 0x7fe40038d4e0>,
#  'education': <gensim.models.keyedvectors.Vocab at 0x7fe40038d518>,
#  'calculated': <gensim.models.keyedvectors.Vocab at 0x7fe40038d550>,
#  'laboratory': <gensim.models.keyedvectors.Vocab at 0x7fe40038d588>,
#  'inflammation': <gensim.models.keyedvectors.Vocab at 0x7fe40038d5c0>,
#  'intracellular': <gensim.models.keyedvectors.Vocab at 0x7fe40038d5f8>,
#  'animal': <gensim.models.keyedvectors.Vocab at 0x7fe40038d668>,
#  'urinary': <gensim.models.keyedvectors.Vocab at 0x7fe40038d6d8>,
#  'hepatic': <gensim.models.keyedvectors.Vocab at 0x7fe40038d748>,
#  'causes': <gensim.models.keyedvectors.Vocab at 0x7fe40038d7b8>,
#  'stroke': <gensim.models.keyedvectors.Vocab at 0x7fe40038d828>,
#  'distinct': <gensim.models.keyedvectors.Vocab at 0x7fe40038d860>,
#  'strong': <gensim.models.keyedvectors.Vocab at 0x7fe40038d8d0>,
#  'spinal': <gensim.models.keyedvectors.Vocab at 0x7fe40038d940>,
#  'viral': <gensim.models.keyedvectors.Vocab at 0x7fe40038d9b0>,
#  'component': <gensim.models.keyedvectors.Vocab at 0x7fe40038d9e8>,
#  'severity': <gensim.models.keyedvectors.Vocab at 0x7fe40038da20>,
#  'people': <gensim.models.keyedvectors.Vocab at 0x7fe40038da90>,
#  'hormone': <gensim.models.keyedvectors.Vocab at 0x7fe40038db00>,
#  'administered': <gensim.models.keyedvectors.Vocab at 0x7fe40038db38>,
#  'measure': <gensim.models.keyedvectors.Vocab at 0x7fe40038dba8>,
#  'mutant': <gensim.models.keyedvectors.Vocab at 0x7fe40038dc18>,
#  'subsequent': <gensim.models.keyedvectors.Vocab at 0x7fe40038dc50>,
#  'ie': <gensim.models.keyedvectors.Vocab at 0x7fe40038dcc0>,
#  'examine': <gensim.models.keyedvectors.Vocab at 0x7fe40038dd30>,
#  'determination': <gensim.models.keyedvectors.Vocab at 0x7fe40038dd68>,
#  'selective': <gensim.models.keyedvectors.Vocab at 0x7fe40038dda0>,
#  'much': <gensim.models.keyedvectors.Vocab at 0x7fe40038de10>,
#  'maximum': <gensim.models.keyedvectors.Vocab at 0x7fe40038de80>,
#  'environmental': <gensim.models.keyedvectors.Vocab at 0x7fe40038deb8>,
#  'community': <gensim.models.keyedvectors.Vocab at 0x7fe40038def0>,
#  'toxicity': <gensim.models.keyedvectors.Vocab at 0x7fe40038df28>,
#  'so': <gensim.models.keyedvectors.Vocab at 0x7fe40038df98>,
#  'repair': <gensim.models.keyedvectors.Vocab at 0x7fe400390048>,
#  'little': <gensim.models.keyedvectors.Vocab at 0x7fe4003900b8>,
#  'malignant': <gensim.models.keyedvectors.Vocab at 0x7fe4003900f0>,
#  'estimated': <gensim.models.keyedvectors.Vocab at 0x7fe400390128>,
#  'highest': <gensim.models.keyedvectors.Vocab at 0x7fe400390198>,
#  'onset': <gensim.models.keyedvectors.Vocab at 0x7fe400390208>,
#  'carried': <gensim.models.keyedvectors.Vocab at 0x7fe400390278>,
#  'regarding': <gensim.models.keyedvectors.Vocab at 0x7fe4003902b0>,
#  'nm': <gensim.models.keyedvectors.Vocab at 0x7fe400390320>,
#  'motor': <gensim.models.keyedvectors.Vocab at 0x7fe400390390>,
#  'anterior': <gensim.models.keyedvectors.Vocab at 0x7fe4003903c8>,
#  'setting': <gensim.models.keyedvectors.Vocab at 0x7fe400390438>,
#  'taken': <gensim.models.keyedvectors.Vocab at 0x7fe4003904a8>,
#  'exposed': <gensim.models.keyedvectors.Vocab at 0x7fe400390518>,
#  'forms': <gensim.models.keyedvectors.Vocab at 0x7fe400390588>,
#  'developing': <gensim.models.keyedvectors.Vocab at 0x7fe4003905c0>,
#  'dysfunction': <gensim.models.keyedvectors.Vocab at 0x7fe4003905f8>,
#  'set': <gensim.models.keyedvectors.Vocab at 0x7fe400390668>,
#  'recorded': <gensim.models.keyedvectors.Vocab at 0x7fe4003906a0>,
#  'needed': <gensim.models.keyedvectors.Vocab at 0x7fe400390710>,
#  'bacteria': <gensim.models.keyedvectors.Vocab at 0x7fe400390748>,
#  'include': <gensim.models.keyedvectors.Vocab at 0x7fe4003907b8>,
#  'objectives': <gensim.models.keyedvectors.Vocab at 0x7fe4003907f0>,
#  'microscopy': <gensim.models.keyedvectors.Vocab at 0x7fe400390828>,
#  'students': <gensim.models.keyedvectors.Vocab at 0x7fe400390860>,
#  'medicine': <gensim.models.keyedvectors.Vocab at 0x7fe400390898>,
#  'sodium': <gensim.models.keyedvectors.Vocab at 0x7fe400390908>,
#  'involvement': <gensim.models.keyedvectors.Vocab at 0x7fe400390940>,
#  'epithelial': <gensim.models.keyedvectors.Vocab at 0x7fe400390978>,
#  'national': <gensim.models.keyedvectors.Vocab at 0x7fe4003909b0>,
#  'selection': <gensim.models.keyedvectors.Vocab at 0x7fe4003909e8>,
#  'alternative': <gensim.models.keyedvectors.Vocab at 0x7fe400390a20>,
#  'point': <gensim.models.keyedvectors.Vocab at 0x7fe400390a90>,
#  'interventions': <gensim.models.keyedvectors.Vocab at 0x7fe400390ac8>,
#  'mental': <gensim.models.keyedvectors.Vocab at 0x7fe400390b38>,
#  'complexes': <gensim.models.keyedvectors.Vocab at 0x7fe400390b70>,
#  'ca2': <gensim.models.keyedvectors.Vocab at 0x7fe400390be0>,
#  'modified': <gensim.models.keyedvectors.Vocab at 0x7fe400390c18>,
#  'indicating': <gensim.models.keyedvectors.Vocab at 0x7fe400390c50>,
#  'relatively': <gensim.models.keyedvectors.Vocab at 0x7fe400390c88>,
#  'alcohol': <gensim.models.keyedvectors.Vocab at 0x7fe400390cf8>,
#  'means': <gensim.models.keyedvectors.Vocab at 0x7fe400390d68>,
#  'enzymes': <gensim.models.keyedvectors.Vocab at 0x7fe400390dd8>,
#  'investigation': <gensim.models.keyedvectors.Vocab at 0x7fe400390e10>,
#  'beta': <gensim.models.keyedvectors.Vocab at 0x7fe400390e80>,
#  '22': <gensim.models.keyedvectors.Vocab at 0x7fe400390ef0>,
#  'seven': <gensim.models.keyedvectors.Vocab at 0x7fe400390f60>,
#  'having': <gensim.models.keyedvectors.Vocab at 0x7fe400390fd0>,
#  'short': <gensim.models.keyedvectors.Vocab at 0x7fe400393080>,
#  'necessary': <gensim.models.keyedvectors.Vocab at 0x7fe4003930b8>,
#  'stability': <gensim.models.keyedvectors.Vocab at 0x7fe4003930f0>,
#  'implications': <gensim.models.keyedvectors.Vocab at 0x7fe400393128>,
#  'treatments': <gensim.models.keyedvectors.Vocab at 0x7fe400393160>,
#  'males': <gensim.models.keyedvectors.Vocab at 0x7fe4003931d0>,
#  'significance': <gensim.models.keyedvectors.Vocab at 0x7fe400393208>,
#  'characterization': <gensim.models.keyedvectors.Vocab at 0x7fe400393240>,
#  'develop': <gensim.models.keyedvectors.Vocab at 0x7fe4003932b0>,
#  'problem': <gensim.models.keyedvectors.Vocab at 0x7fe400393320>,
#  'activated': <gensim.models.keyedvectors.Vocab at 0x7fe400393358>,
#  'advanced': <gensim.models.keyedvectors.Vocab at 0x7fe400393390>,
#  'terms': <gensim.models.keyedvectors.Vocab at 0x7fe400393400>,
#  'internal': <gensim.models.keyedvectors.Vocab at 0x7fe400393438>,
#  'amount': <gensim.models.keyedvectors.Vocab at 0x7fe4003934a8>,
#  'environment': <gensim.models.keyedvectors.Vocab at 0x7fe4003934e0>,
#  'approaches': <gensim.models.keyedvectors.Vocab at 0x7fe400393518>,
#  'exhibited': <gensim.models.keyedvectors.Vocab at 0x7fe400393550>,
#  'linear': <gensim.models.keyedvectors.Vocab at 0x7fe4003935c0>,
#  'memory': <gensim.models.keyedvectors.Vocab at 0x7fe400393630>,
#  'intake': <gensim.models.keyedvectors.Vocab at 0x7fe4003936a0>,
#  'reactions': <gensim.models.keyedvectors.Vocab at 0x7fe4003936d8>,
#  '19': <gensim.models.keyedvectors.Vocab at 0x7fe400393748>,
#  'mitochondrial': <gensim.models.keyedvectors.Vocab at 0x7fe400393780>,
#  'peak': <gensim.models.keyedvectors.Vocab at 0x7fe4003937f0>,
#  'plant': <gensim.models.keyedvectors.Vocab at 0x7fe400393860>,
#  'females': <gensim.models.keyedvectors.Vocab at 0x7fe4003938d0>,
#  'lack': <gensim.models.keyedvectors.Vocab at 0x7fe400393940>,
#  'resonance': <gensim.models.keyedvectors.Vocab at 0x7fe400393978>,
#  'strategy': <gensim.models.keyedvectors.Vocab at 0x7fe4003939b0>,
#  'position': <gensim.models.keyedvectors.Vocab at 0x7fe4003939e8>,
#  'contribute': <gensim.models.keyedvectors.Vocab at 0x7fe400393a20>,
#  'hypothesis': <gensim.models.keyedvectors.Vocab at 0x7fe400393a58>,
#  'diabetic': <gensim.models.keyedvectors.Vocab at 0x7fe400393a90>,
#  'physiological': <gensim.models.keyedvectors.Vocab at 0x7fe400393ac8>,
#  'dependent': <gensim.models.keyedvectors.Vocab at 0x7fe400393b00>,
#  'appears': <gensim.models.keyedvectors.Vocab at 0x7fe400393b70>,
#  'occur': <gensim.models.keyedvectors.Vocab at 0x7fe400393be0>,
#  'eight': <gensim.models.keyedvectors.Vocab at 0x7fe400393c50>,
#  'able': <gensim.models.keyedvectors.Vocab at 0x7fe400393cc0>,
#  'appropriate': <gensim.models.keyedvectors.Vocab at 0x7fe400393cf8>,
#  'extent': <gensim.models.keyedvectors.Vocab at 0x7fe400393d68>,
#  'accumulation': <gensim.models.keyedvectors.Vocab at 0x7fe400393da0>,
#  'directly': <gensim.models.keyedvectors.Vocab at 0x7fe400393dd8>,
#  'underlying': <gensim.models.keyedvectors.Vocab at 0x7fe400393e10>,
#  'best': <gensim.models.keyedvectors.Vocab at 0x7fe400393e80>,
#  'frequently': <gensim.models.keyedvectors.Vocab at 0x7fe400393eb8>,
#  'accuracy': <gensim.models.keyedvectors.Vocab at 0x7fe400393ef0>,
#  'cholesterol': <gensim.models.keyedvectors.Vocab at 0x7fe400393f28>,
#  'isolates': <gensim.models.keyedvectors.Vocab at 0x7fe400393f60>,
#  'matrix': <gensim.models.keyedvectors.Vocab at 0x7fe400393fd0>,
#  'prostate': <gensim.models.keyedvectors.Vocab at 0x7fe400397048>,
#  'host': <gensim.models.keyedvectors.Vocab at 0x7fe4003970b8>,
#  'images': <gensim.models.keyedvectors.Vocab at 0x7fe400397128>,
#  'late': <gensim.models.keyedvectors.Vocab at 0x7fe400397198>,
#  'inhibitory': <gensim.models.keyedvectors.Vocab at 0x7fe4003971d0>,
#  'relation': <gensim.models.keyedvectors.Vocab at 0x7fe400397208>,
#  'sleep': <gensim.models.keyedvectors.Vocab at 0x7fe400397278>,
#  '35': <gensim.models.keyedvectors.Vocab at 0x7fe4003972e8>,
#  'along': <gensim.models.keyedvectors.Vocab at 0x7fe400397358>,
#  'source': <gensim.models.keyedvectors.Vocab at 0x7fe4003973c8>,
#  'partial': <gensim.models.keyedvectors.Vocab at 0x7fe400397438>,
#  'public': <gensim.models.keyedvectors.Vocab at 0x7fe4003974a8>,
#  'cortex': <gensim.models.keyedvectors.Vocab at 0x7fe400397518>,
#  '05': <gensim.models.keyedvectors.Vocab at 0x7fe400397588>,
#  'compare': <gensim.models.keyedvectors.Vocab at 0x7fe4003975f8>,
#  'corresponding': <gensim.models.keyedvectors.Vocab at 0x7fe400397630>,
#  'mainly': <gensim.models.keyedvectors.Vocab at 0x7fe4003976a0>,
#  'differential': <gensim.models.keyedvectors.Vocab at 0x7fe4003976d8>,
#  'iv': <gensim.models.keyedvectors.Vocab at 0x7fe400397748>,
#  '28': <gensim.models.keyedvectors.Vocab at 0x7fe4003977b8>,
#  'fatty': <gensim.models.keyedvectors.Vocab at 0x7fe400397828>,
#  'phosphorylation': <gensim.models.keyedvectors.Vocab at 0x7fe400397860>,
#  'confidence': <gensim.models.keyedvectors.Vocab at 0x7fe400397898>,
#  '90': <gensim.models.keyedvectors.Vocab at 0x7fe400397908>,
#  'fetal': <gensim.models.keyedvectors.Vocab at 0x7fe400397978>,
#  '80': <gensim.models.keyedvectors.Vocab at 0x7fe4003979e8>,
#  'efficiency': <gensim.models.keyedvectors.Vocab at 0x7fe400397a20>,
#  'infected': <gensim.models.keyedvectors.Vocab at 0x7fe400397a58>,
#  'reference': <gensim.models.keyedvectors.Vocab at 0x7fe400397a90>,
#  'relevant': <gensim.models.keyedvectors.Vocab at 0x7fe400397ac8>,
#  'open': <gensim.models.keyedvectors.Vocab at 0x7fe400397b38>,
#  'shows': <gensim.models.keyedvectors.Vocab at 0x7fe400397ba8>,
#  'processing': <gensim.models.keyedvectors.Vocab at 0x7fe400397be0>,
#  'composition': <gensim.models.keyedvectors.Vocab at 0x7fe400397c18>,
#  'oxidative': <gensim.models.keyedvectors.Vocab at 0x7fe400397c50>,
#  'reviewed': <gensim.models.keyedvectors.Vocab at 0x7fe400397c88>,
#  'l': <gensim.models.keyedvectors.Vocab at 0x7fe400397cc0>,
#  'hepatitis': <gensim.models.keyedvectors.Vocab at 0x7fe400397cf8>,
#  'aspects': <gensim.models.keyedvectors.Vocab at 0x7fe400397d68>,
#  'predicted': <gensim.models.keyedvectors.Vocab at 0x7fe400397da0>,
#  'cervical': <gensim.models.keyedvectors.Vocab at 0x7fe400397dd8>,
#  'leading': <gensim.models.keyedvectors.Vocab at 0x7fe400397e48>,
#  'reports': <gensim.models.keyedvectors.Vocab at 0x7fe400397eb8>,
#  'tool': <gensim.models.keyedvectors.Vocab at 0x7fe400397f28>,
#  ...}
