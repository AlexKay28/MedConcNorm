# %%
from sentence_transformers import SentenceTransformer
model = SentenceTransformer('xlm-roberta-base')

# %%
import pandas as pd

df = pd.DataFrame(['This framework generates embeddings for each input sentence',
    'Sentences are passed as a list of string.', 
    'The quick brown fox jumps over the lazy dog.'])
df
# Out:
#                                                    0
# 0  This framework generates embeddings for each i...
# 1          Sentences are passed as a list of string.
# 2       The quick brown fox jumps over the lazy dog.

# %%
model.encode("This is sentence")
# Out:
# array([ 8.91979132e-03,  3.13641801e-02,  1.38542559e-02,  4.93207760e-02,
#         8.89573917e-02, -6.86677843e-02, -1.06541617e-02,  4.47435975e-02,
#         2.66650952e-02, -5.92151955e-02,  6.37441874e-02,  4.07671779e-02,
#         8.25259835e-02,  3.42205577e-02, -5.02290437e-03,  2.60452833e-02,
#        -1.62775349e-02, -4.59257588e-02, -1.04579655e-02,  2.26466078e-02,
#         3.72367427e-02,  1.57570746e-02,  3.23899016e-02,  4.69418280e-02,
#         1.30457180e-02,  5.53821353e-03, -2.60002799e-02,  5.58344722e-02,
#         7.00472016e-03,  5.82497492e-02,  6.78133965e-02, -3.57365087e-02,
#         8.04919470e-03,  6.95021600e-02,  1.66558363e-02, -3.28455567e-02,
#        -7.57132024e-02, -7.75924623e-02,  5.53102382e-02,  6.24953285e-02,
#         1.00450180e-01,  7.84775317e-02,  2.34421194e-02,  2.45276932e-02,
#        -5.04063908e-03, -2.98098437e-02,  3.76170278e-02, -2.06816383e-02,
# ...

# %%
sentence_embeddings = model.encode(df[0])

# %%
sentence_embeddings.shape
# Out:
# (3, 768)

# %%
df['lol'] = sentence_embeddings.tolist()

# %%
df
# Out:
#                                                    0  \
# 0  This framework generates embeddings for each i...
# 1          Sentences are passed as a list of string.
# 2       The quick brown fox jumps over the lazy dog.
#
#                                                  lol
# 0  [-0.018096445128321648, -0.019842060282826424,...
# 1  [-0.014430545270442963, 0.00594680430367589, 0...
# 2  [0.00633607292547822, 0.05626474693417549, 0.0...

# %%
for sentence, embedding in zip(df[0], sentence_embeddings):
    print("Sentence:", sentence)
    print("Embedding:", embedding)
    print("")
# Out:
# Sentence: This framework generates embeddings for each input sentence
# Embedding: [-1.80964451e-02 -1.98420603e-02  2.46165674e-02  9.10398141e-02
#   2.06275415e-02 -3.83480527e-02  2.07308419e-02  7.80211538e-02
#   6.46610931e-02 -4.13624570e-02  1.84914738e-01  6.59896359e-02
#   7.10837170e-02 -1.17487088e-02  1.44400680e-02 -2.23153620e-03
#  -2.54501216e-02 -3.08153238e-02  1.21084154e-02 -2.45573986e-02
#  -6.75370218e-03  3.98033373e-02  7.25199804e-02  5.53413592e-02
#  -1.74770840e-02  5.45764267e-02 -2.22186111e-02 -1.22223403e-02
#   3.12292408e-02  8.13307017e-02  9.51849297e-02 -4.25638929e-02
#   4.14908789e-02  2.15152670e-02  2.98937168e-02 -5.76258264e-02
#   4.11735103e-02 -4.48185839e-02 -2.69215107e-02 -2.41257884e-02
#   9.91577357e-02  4.22818325e-02  1.09161697e-01  1.00795459e-02
#   5.99169210e-02  6.60474896e-02  5.61660193e-02 -5.84473833e-03
#   2.70744115e-02 -6.22706413e-02  6.47278428e-02 -5.27566038e-02
# ...

# %%
len(embedding)
# Out:
# 768
